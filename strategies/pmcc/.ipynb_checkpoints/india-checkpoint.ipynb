# %%
from datetime import datetime, timedelta, date
import pandas as pd
import requests
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns
from SmartApi import SmartConnect
from pyotp import TOTP
import requests
from SmartApi.smartWebSocketV2 import SmartWebSocketV2
import time
from dotenv import load_dotenv
import os
import threading

# %% [markdown]
# ### India VIX calculation

# %%
start_date = (datetime.today() - timedelta(days=365)).date()
df = yf.download("^INDIAVIX", start=start_date)

iv = np.array(df['Close'])
temp = []
for i in iv:
    temp.append(i[0])
iv = np.array(temp)
del temp, i
current_iv = iv[-1]       
iv_min = np.min(iv)             
iv_max = np.max(iv)             

# IV Rank = (Current IV - Min IV) / (Max IV - Min IV) * 100
iv_rank = (current_iv - iv_min) / (iv_max - iv_min) * 100

# IV Percentile = % of days IV was below current IV
iv_percentile = np.sum(iv <= current_iv) / len(iv) * 100

print(f"Today's IV: {current_iv:.2f}")
print(f"IV Rank: {iv_rank:.2f}%")
print(f"IV Percentile: {iv_percentile:.2f}%")

# %% [markdown]
# ### EDA

# %%
start_date = (datetime.today() - timedelta(days=365)).date()
end_date = datetime.today().date()
nifty = yf.download("^NSEI", start=start_date, end=end_date)['Close']
vix = yf.download("^INDIAVIX", start=start_date, end=end_date)['Close']
fig, ax1 = plt.subplots(figsize=(12,6))

color = 'tab:blue'
ax1.set_xlabel('Date')
ax1.set_ylabel('NIFTY50', color=color)
ax1.plot(nifty.index, nifty.values, color=color, label='NIFTY50')
ax1.tick_params(axis='y', labelcolor=color)
ax2 = ax1.twinx()
plt.grid(False)
color = 'tab:red'
ax2.set_ylabel('IV', color=color)
color = 'tab:red'
ax2.set_ylabel('India VIX', color=color)
ax2.plot(vix.index, vix.values, color=color, label='India VIX')
ax2.tick_params(axis='y', labelcolor=color)
fig.suptitle("NIFTY50 vs India VIX (Last 1 Year)")
fig.tight_layout()
plt.show();

# %%
combined = pd.concat([nifty, vix], axis=1)
combined.columns = ['NIFTY50', 'INDIAVIX']  
sns.heatmap(combined.corr(), annot=True);

# %%
yf.download("^NSEI")['Close'].iloc[-1]
# Out:
# [*********************100%***********************]  1 of 1 completed
# Ticker
# ^NSEI    22819.599609
# Name: 2026-03-27 00:00:00, dtype: float64

# %%
url = 'https://margincalculator.angelbroking.com/OpenAPI_File/files/OpenAPIScripMaster.json'
d = requests.get(url).json()
token_df = pd.DataFrame(d)
token_df['expiry'] = pd.to_datetime(token_df['expiry'], format='mixed').dt.date
token_df['strike'] = pd.to_numeric(token_df['strike'], errors='coerce')
nifty_calls = token_df[(token_df['name'] == 'NIFTY') & (token_df['instrumenttype'] == 'OPTIDX')].copy()

# Separate CE and PE, sort by expiry and strike
nifty_calls['option_type'] = nifty_calls['symbol'].str[-2:] 
nifty_calls = nifty_calls.sort_values(['expiry', 'strike']).reset_index(drop=True)
nifty_calls = nifty_calls[nifty_calls['option_type']=='CE']
nifty = nifty_calls[['token', 'symbol', 'name', 'expiry', 'strike']]
nifty = nifty.copy()
nifty['expiry'] = pd.to_datetime(nifty['expiry'])
nifty['strike'] = nifty['strike'] / 100

spot = 22331.4
today = pd.to_datetime('today').normalize()

long_calls = nifty[(nifty['strike'] >= spot*0.60) & (nifty['strike'] <= spot) &
    (nifty['expiry'] >= today + pd.Timedelta(days=90)) & (nifty['expiry'] <= today + pd.Timedelta(days=150))].copy()

short_calls = nifty[(nifty['strike'] >= spot) & (nifty['strike'] <= spot*1.3) &
    (nifty['expiry'] >= today + pd.Timedelta(days=10)) & (nifty['expiry'] <= today + pd.Timedelta(days=30))].copy()

temp = pd.concat([long_calls, short_calls])
tokens = list(temp['token'])
tokens[:5]
# Out:
# ['50447', '55181', '50556', '39989', '55183']

# %%
nifty.head()
# Out:
#    token               symbol   name     expiry   strike
# 0  40566  NIFTY07APR2620200CE  NIFTY 2026-04-07  20200.0
# 2  40568  NIFTY07APR2620250CE  NIFTY 2026-04-07  20250.0
# 4  40570  NIFTY07APR2620300CE  NIFTY 2026-04-07  20300.0
# 7  40572  NIFTY07APR2620350CE  NIFTY 2026-04-07  20350.0
# 9  40575  NIFTY07APR2620400CE  NIFTY 2026-04-07  20400.0

# %% [markdown]
# ### Angel One

# %%
# Creds
load_dotenv()
api_key = os.getenv("API_KEY")
client_code = os.getenv("CLIENT_CODE")
pwd = os.getenv("PWD")
totp = os.getenv("TOTP_KEY")

# Connection
obj = SmartConnect(api_key=api_key)
session = obj.generateSession(client_code, pwd, TOTP(totp).now())
refreshToken = session['data']['refreshToken']
authToken = session['data']['jwtToken']
feedToken = obj.getfeedToken()
res = obj.getProfile(refreshToken)
obj.generateToken(refreshToken)
res=res['data']['exchanges']
# Out:
# [I 260401 00:20:22 smartConnect:124] in pool

# %%
# ---------WebSocketV2---------
sws = SmartWebSocketV2(authToken, api_key, client_code, feedToken, max_retry_attempt=0)
correlation_id = "abcd"
action = 1
mode = 3
latest = {}
token_list = [{"exchangeType": 2, "tokens": tokens}]

def on_open(wsapp):
    print("on open")
    sws.subscribe(correlation_id, mode, token_list)

def on_data(wsapp, message):
    token = message['token']
    latest[token] = message
    print(f"{token}", end=", ")

def on_error(wsapp, error):
    print(error)

def on_close(wsapp):
    print("Close")

def close_connection():
    sws.close_connection()

sws.on_open = on_open
sws.on_data = on_data
sws.on_error = on_error
sws.on_close = on_close

ws_thread = threading.Thread(target=sws.connect)
ws_thread.daemon = True
ws_thread.start()
time.sleep(5)
sws.close_connection()
print("Done")
# Out:
# on open
# 72218 data received.
# 72339 data received.
# 54908 data received.
# 72216 data received.
# 72337 data received.
# 54906 data received.
# 72459 data received.
# 72214 data received.
# 72335 data received.
# 72457 data received.
# 72212 data received.
# 72333 data received.
# 72210 data received.
# 72331 data received.
# 63504 data received.
# 63506 data received.
# 54912 data received.
# 50556 data received.
# 54910 data received.
# 72348 data received.
# 72228 data received.
# 72346 data received.
# 72467 data received.
# 72226 data received.
# 72224 data received.
# 72342 data received.
# 63512 data received.
# 72222 data received.
# 72220 data received.
# 54802 data received.
# 54800 data received.
# 54806 data received.
# 50447 data received.
# 39989 data received.
# 54804 data received.
# 54808 data received.
# 72357 data received.
# 63400 data received.
# 63402 data received.
# 72354 data received.
# 63404 data received.
# 63406 data received.
# 72350 data received.
# 63408 data received.
# 54812 data received.
# 54810 data received.
# 54816 data received.
# 72249 data received.
# 54818 data received.
# 72489 data received.
# 72369 data received.
# 63410 data received.
# 72487 data received.
# 72246 data received.
# 72367 data received.
# 63412 data received.
# 72485 data received.
# 72244 data received.
# 72365 data received.
# 63414 data received.
# 72483 data received.
# 63416 data received.
# 72361 data received.
# 54703 data received.
# 54701 data received.
# 54821 data received.
# 54707 data received.
# 54705 data received.
# 71965 data received.
# 71963 data received.
# 63420 data received.
# 72259 data received.
# 63422 data received.
# 72257 data received.
# 63424 data received.
# 72255 data received.
# 72497 data received.
# 63426 data received.
# 72253 data received.
# 72495 data received.
# 63428 data received.
# 72251 data received.
# 72493 data received.
# 72491 data received.
# 54835 data received.
# 54833 data received.
# 54711 data received.
# 63430 data received.
# 72269 data received.
# 72267 data received.
# 63434 data received.
# 72265 data received.
# 63436 data received.
# 72263 data received.
# 72385 data received.
# 72261 data received.
# 72383 data received.
# 54962 data received.
# 51453 data received.
# 54966 data received.
# 54964 data received.
# 71967 data received.
# 54968 data received.
# 72713 data received.
# 63444 data received.
# 72158 data received.
# 72279 data received.
# 72277 data received.
# 63447 data received.
# 72395 data received.
# 72271 data received.
# 54970 data received.
# 54974 data received.
# 54972 data received.
# 54978 data received.
# 54976 data received.
# 72725 data received.
# 72723 data received.
# 72721 data received.
# 63336 data received.
# 63458 data received.
# 63339 data received.
# 72162 data received.
# 72160 data received.
# 54980 data received.
# 54864 data received.
# 54984 data received.
# 54982 data received.
# 54868 data received.
# 54988 data received.
# 54866 data received.
# 72719 data received.
# 72733 data received.
# 63342 data received.
# 63464 data received.
# 63344 data received.
# 63466 data received.
# 63346 data received.
# 63468 data received.
# 54870 data received.
# 54990 data received.
# 54874 data received.
# 54872 data received.
# 54757 data received.
# 54878 data received.
# 54755 data received.
# 54876 data received.
# 72729 data received.
# 54759 data received.
# 72727 data received.
# 63470 data received.
# 72747 data received.
# 63472 data received.
# 72745 data received.
# 63353 data received.
# 63474 data received.
# 72743 data received.
# 63355 data received.
# 63476 data received.
# 72741 data received.
# 63357 data received.
# 63478 data received.
# 72065 data received.
# 54761 data received.
# 54882 data received.
# 54880 data received.
# 54765 data received.
# 54886 data received.
# 54763 data received.
# 54884 data received.
# 54769 data received.
# 54767 data received.
# 54888 data received.
# 63361 data received.
# 63482 data received.
# 63484 data received.
# 72756 data received.
# 63364 data received.
# 63486 data received.
# 72754 data received.
# 63366 data received.
# 72199 data received.
# 55181 data received.
# 72750 data received.
# 72197 data received.
# 72195 data received.
# 55183 data received.
# 54771 data received.
# 54892 data received.
# 54890 data received.
# 54775 data received.
# 54773 data received.
# 54779 data received.
# 54777 data received.
# 63480 data received.
# 63492 data received.
# 63494 data received.
# 63374 data received.
# 63496 data received.
# 72764 data received.
# 63376 data received.
# 63498 data received.
# 72762 data received.
# 63378 data received.
# 72760 data received.
# 54788 data received.
# 63490 data received.
# 63370 data received.
# 63382 data received.
# 63384 data received.
# 63386 data received.
# 63388 data received.
# 72771 data received.
# 54790 data received.
# 54794 data received.
# 54792 data received.
# 54798 data received.
# 54796 data received.
# 63380 data received.
# 72427 data received.
# 72669 data received.
# 63394 data received.
# 72667 data received.
# 63396 data received.
# 72665 data received.
# 63398 data received.
# 72424 data received.
# 72663 data received.
# 72422 data received.
# 63390 data received.
# 63392 data received.
# 72419 data received.
# 72317 data received.
# 72439 data received.
# 72437 data received.
# 72434 data received.
# 72312 data received.
# 72431 data received.
# 54695 data received.
# 54699 data received.
# 54697 data received.
# 72429 data received.
# 72207 data received.
# 72329 data received.
# 72205 data received.
# 72327 data received.
# 72203 data received.
# 72325 data received.
# 72201 data received.
# 72323 data received.
# 72441 data received.
# 54904 data received.
# 54902 data received.
# Connection closedDone
# [W 260330 18:15:03 smartWebSocketV2:342] Connection closed due to max retry attempts reached.

# %%
long_tokens  = set(long_calls['token'].astype(str).tolist())
short_tokens = set(short_calls['token'].astype(str).tolist())

LIQUIDITY_KEYS = [
    'last_traded_quantity',
    'average_traded_price',
    'volume_trade_for_the_day',
    'total_buy_quantity',
    'total_sell_quantity',
    'open_price_of_the_day',
    'high_price_of_the_day',
    'low_price_of_the_day',
    'last_traded_timestamp',
    'open_interest'
]

def is_valid_tick(tick):
    # Basic zero checks
    if not all(tick.get(k, 0) != 0 for k in LIQUIDITY_KEYS):
        return False
    
    # Best 5 sell side must have at least 1 valid order
    sell_side = tick.get('best_5_sell_data', [])
    if not any(d['price'] != 0 and d['quantity'] != 0 for d in sell_side):
        return False

    # Best 5 buy side must have at least 1 valid order
    buy_side = tick.get('best_5_buy_data', [])
    if not any(d['price'] != 0 and d['quantity'] != 0 for d in buy_side):
        return False

    return True

latest = {token: tick for token, tick in latest.items() if is_valid_tick(tick)}

long_df  = {token: tick for token, tick in latest.items() if token in long_tokens}
short_df = {token: tick for token, tick in latest.items() if token in short_tokens}

# %%
len(long_df)
len(short_df)
# Out:
# 174

# %%
params = {"name": "NIFTY", "expirydate": "26MAY2026"}
temp = obj.optionGreek(params)
temp
# Out:
# {'status': True,
#  'message': 'SUCCESS',
#  'errorcode': '',
#  'data': [{'name': 'TCS',
#    'expiry': '26MAY2026',
#    'strikePrice': '2800.000000',
#    'optionType': 'CE',
#    'delta': '0.121900',
#    'gamma': '0.000800',
#    'theta': '-0.514600',
#    'vega': '1.928800',
#    'impliedVolatility': '27.070000',
#    'tradeVolume': '3.00'},
#   {'name': 'TCS',
#    'expiry': '26MAY2026',
#    'strikePrice': '2400.000000',
#    'optionType': 'PE',
#    'delta': '-0.334300',
#    'gamma': '0.001500',
#    'theta': '-0.546100',
#    'vega': '3.473600',
#    'impliedVolatility': '34.710000',
#    'tradeVolume': '2.00'}]}

# %%
obj.putCallRatio()
# Out:
# {'status': True,
#  'message': 'SUCCESS',
#  'errorcode': '',
#  'data': [{'pcr': 0.0, 'tradingSymbol': '330MAR2630MAR26FUT'},
#   {'pcr': 0.0, 'tradingSymbol': 'ABB30MAR26FUT'},
#   {'pcr': 0.0, 'tradingSymbol': 'ABCAPITAL30MAR26FUT'},
#   {'pcr': 0.0, 'tradingSymbol': 'ADANIENSOL30MAR26FUT'},
#   {'pcr': 0.0, 'tradingSymbol': 'ADANIENT30MAR26FUT'},
#   {'pcr': 0.0, 'tradingSymbol': 'ADANIGREEN30MAR26FUT'},
#   {'pcr': 0.0, 'tradingSymbol': 'ADANIPORTS30MAR26FUT'},
#   {'pcr': 0.0, 'tradingSymbol': 'ALKEM30MAR26FUT'},
#   {'pcr': 0.0, 'tradingSymbol': 'AMBER30MAR26FUT'},
#   {'pcr': 0.0, 'tradingSymbol': 'AMBUJACEM30MAR26FUT'},
#   {'pcr': 0.0, 'tradingSymbol': 'ANGELONE30MAR26FUT'},
#   {'pcr': 0.0, 'tradingSymbol': 'APLAPOLLO30MAR26FUT'},
#   {'pcr': 0.0, 'tradingSymbol': 'APOLLOHOSP30MAR26FUT'},
#   {'pcr': 0.0, 'tradingSymbol': 'ASHOKLEY30MAR26FUT'},
#   {'pcr': 0.0, 'tradingSymbol': 'ASIANPAINT30MAR26FUT'},
#   {'pcr': 0.0, 'tradingSymbol': 'ASTRAL30MAR26FUT'},
#   {'pcr': 0.0, 'tradingSymbol': 'AUBANK30MAR26FUT'},
#   {'pcr': 0.0, 'tradingSymbol': 'AUROPHARMA30MAR26FUT'},
#   {'pcr': 0.0, 'tradingSymbol': 'AXISBANK30MAR26FUT'},
#   {'pcr': 0.0, 'tradingSymbol': 'BAJAJ-AUTO30MAR26FUT'},
#   {'pcr': 0.0, 'tradingSymbol': 'BAJAJFINSV30MAR26FUT'},
#   {'pcr': 0.0, 'tradingSymbol': 'BAJAJHLDNG30MAR26FUT'},
#   {'pcr': 0.0, 'tradingSymbol': '